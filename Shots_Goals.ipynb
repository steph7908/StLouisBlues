# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import seaborn as sns
color_map = plt.cm.winter
from matplotlib.patches import RegularPolygon
import math
from PIL import Image
from IPython.display import Image

# %% [markdown]
# # 2018-2019 Stanley Cup Final
# ## Game 6 vs Game 7 Shots on Goal
# ## _Boston Bruins vs St Louis Blues_
# -----

# %%
# File to Load (loading clean data without index change)
file_to_load = "Gm6_data_clean.csv"

# Read and store into Pandas data frame
gm_6 = pd.read_csv(file_to_load)

#Let's first look at shots per period
first_period_shots_gm6 = gm_6.loc[((gm_6['event'] == 'Shot') | (gm_6['event'] == 'Goal')) & (gm_6['period'] == 1)]
second_period_shots_gm6 = gm_6.loc[((gm_6['event'] == 'Shot') | (gm_6['event'] == 'Goal')) & (gm_6['period'] == 2)]
third_period_shots_gm6 = gm_6.loc[((gm_6['event'] == 'Shot') | (gm_6['event'] == 'Goal')) & (gm_6['period'] == 3)]

# %%
fig, ax = plt.subplots()
x = range(120)
y = range(50)

ax.imshow(img, extent=[-110, 110, -50, 50])
scalingx=width/100-0.6;
scalingy=height/100+0.5;
x_trans=30;
y_trans=height/2

S = 3.8*scalingx;
# sns.scatterplot(x="x", y="y",
#               hue="event",
#               data=first_period_shots_gm6);

sns.scatterplot(x="x", y="y",
              hue="team_id_for", palette=['yellow','blue'],
              size = "event", sizes = (70,20), size_order=['Shot','Goal'],
              legend = 'full',
              data=first_period_shots_gm6);
plt.title("Game 6:  First period shots on Goal (6/9/19)")
leg = plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
new_labels = ['Team', 'Bruins', 'Blues', '']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

# plt.savefig('Gm6_P1_shots.png')

# %% [markdown]
# Shots are pretty even through the period\
# Bruins:  11    Blues:  9\
# Period end:  Bruins lead 1-0

# %%
fig, ax = plt.subplots()
x = range(120)
y = range(50)

ax.imshow(img, extent=[-110, 110, -50, 50])
scalingx=width/100-0.6;
scalingy=height/100+0.5;
x_trans=30;
y_trans=height/2

S = 3.8*scalingx;
# sns.scatterplot(x="x", y="y",
#               hue="event",
#               data=second_period_shots_gm6);

sns.scatterplot(x="x", y="y",
              hue="team_id_for", palette=['yellow','blue'],
              size = "event", sizes = (70,20), size_order=['Shot','Goal'],
              legend = 'full',
              data=second_period_shots_gm6);
plt.title("Game 6:  Second period shots on Goal (6/9/19)")
leg = plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
new_labels = ['Team', 'Bruins', 'Blues', '']
for t, l in zip(leg.texts, new_labels): t.set_text(l)

# plt.savefig('Gm6_P2_shots.png')

# %% [markdown]
# Shots are again pretty even through the period\
# Bruins:  8    Blues:  10\
# Period end:  Bruins lead 1-0

# %%
fig, ax = plt.subplots()
x = range(120)
y = range(50)

ax.imshow(img, extent=[-110, 110, -50, 50])
scalingx=width/100-0.6;
scalingy=height/100+0.5;
x_trans=30;
y_trans=height/2

S = 3.8*scalingx;
# sns.scatterplot(x="x", y="y",
#               hue="event",
#               data=third_period_shots_gm6);

sns.scatterplot(x="x", y="y",
              hue="team_id_for", palette=['yellow','blue'],
              size = "event", sizes = (70,20), size_order=['Shot','Goal'],
              legend = 'full',
              data=third_period_shots_gm6);
plt.title("Game 6:  Third period shots on Goal (6/9/19)")
leg = plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
new_labels = ['Team', 'Bruins', 'Blues', '']
for t, l in zip(leg.texts, new_labels): t.set_text(l)
    
# plt.savefig('Gm6_P3_shots.png')

# %% [markdown]
# Shots pretty even but the Blues were outscored 4-1\
# Bruins:  12    Blues:  10

# %%
Image(filename='Data/Gm6.png')

# %% [markdown]
# ## Let's look at shots on goal for Game 7
#
# ## Final game of the season for both teams
# Whose ready?

# %%
# File to Load (loading clean data without index change)
file_to_load = "Gm7_data_clean.csv"

# Read and store into Pandas data frame
gm_7 = pd.read_csv(file_to_load)

#Let's first look at shots per period
first_period_shots_gm7 = gm_7.loc[((gm_7['event'] == 'Shot') | (gm_7['event'] == 'Goal')) & (gm_7['period'] == 1)]
second_period_shots_gm7 = gm_7.loc[((gm_7['event'] == 'Shot') | (gm_7['event'] == 'Goal')) & (gm_7['period'] == 2)]
third_period_shots_gm7 = gm_7.loc[((gm_7['event'] == 'Shot') | (gm_7['event'] == 'Goal')) & (gm_7['period'] == 3)]

# %%
fig, ax = plt.subplots()
x = range(120)
y = range(50)

ax.imshow(img, extent=[-110, 110, -50, 50])
scalingx=width/100-0.6;
scalingy=height/100+0.5;
x_trans=30;
y_trans=height/2

S = 3.8*scalingx;
# sns.scatterplot(x="x", y="y",
#               hue="event",
#               data=first_period_shots_gm7);

sns.scatterplot(x="x", y="y",
              hue="team_id_for", palette=['yellow','blue'],
              size = "event", sizes = (70,20), size_order=['Shot','Goal'],
              legend = 'full',
              data=first_period_shots_gm7);
plt.title("Game 7:  First period shots on Goal (6/12/19)")
leg = plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
new_labels = ['Team', 'Bruins', 'Blues', '']
for t, l in zip(leg.texts, new_labels): t.set_text(l)
    
# plt.savefig('Gm7_P1_shots.png')

# %% [markdown]
# Bruins controlled most of the period.\
# They outshot the Blues, 12-4.\
# However, the Blues outscored the Bruins.\
# Period end:  Blues leading 2-0

# %%
fig, ax = plt.subplots()
x = range(120)
y = range(50)

ax.imshow(img, extent=[-110, 110, -50, 50])
scalingx=width/100-0.6;
scalingy=height/100+0.5;
x_trans=30;
y_trans=height/2

S = 3.8*scalingx;
# sns.scatterplot(x="x", y="y",
#               hue="event",
#               data=second_period_shots_gm7);

sns.scatterplot(x="x", y="y",
              hue="team_id_for", palette=['yellow','blue'],
              size = "event", sizes = (70,20), size_order=['Shot','Goal'],
              legend = 'full',
              data=second_period_shots_gm7);
plt.title("Game 7:  Second period shots on Goal (6/12/19)")
leg = plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
new_labels = ['Team', 'Bruins', 'Blues', '']
for t, l in zip(leg.texts, new_labels): t.set_text(l)
    
# plt.savefig('Gm7_P2_shots.png')

# %% [markdown]
# Neither team scored.\
# Bruins kept up the pressure, outshooting the Blues 11-6.\
# Period end:  Blues leading 2-1

# %%
fig, ax = plt.subplots()
x = range(120)
y = range(50)

ax.imshow(img, extent=[-110, 110, -50, 50])
scalingx=width/100-0.6;
scalingy=height/100+0.5;
x_trans=30;
y_trans=height/2

S = 3.8*scalingx;
# sns.scatterplot(x="x", y="y",
#               hue="event",
#               data=third_period_shots_gm7);

sns.scatterplot(x="x", y="y",
              hue="team_id_for", palette=['yellow','blue'],
              size = "event", sizes = (70,20), size_order=['Shot','Goal'],
              legend = 'full',
              data=third_period_shots_gm7);
plt.title("Game 7:  Third period shots on Goal (6/12/19)")
leg = plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
new_labels = ['Team', 'Bruins', 'Blues', '']
for t, l in zip(leg.texts, new_labels): t.set_text(l)
    
# plt.savefig('Gm7_P3_shots.png')

# %% [markdown]
# Shots were pretty even but Blues scored 2 more goals before the Bruins scored their lone goal.\

# %%
Image(filename='Data/Gm7.png')

# %%
Image(filename='Img/2019-NHL-Champions-St.-Louis-Blues.jpg')
